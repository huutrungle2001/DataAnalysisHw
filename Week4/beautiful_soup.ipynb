# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_soup(url):
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'html.parser')
    return soup

# %%
def get_product_urls(soup):
    return [link.get('href') for link in soup.find_all(
        'a', class_='product-item-link', href=True)]

# %%
def get_product_info(soup):
    product_info = {}
    product_info['name'] = soup.find('span', itemprop="name").text
    product_attr = soup.find('tbody').find_all('tr')
    for attr in product_attr:
        key = attr.find('th').text
        value = attr.find('td').text
        product_info[key] = value
    return product_info

# %%
base_url = "https://www.yonex.com/badminton/racquets"

urls = [base_url]
for p in range (2, 8):
    urls.append(base_url + '?p=' + str(p))

urls
# Out:
# ['https://www.yonex.com/badminton/racquets',
#  'https://www.yonex.com/badminton/racquets?p=2',
#  'https://www.yonex.com/badminton/racquets?p=3',
#  'https://www.yonex.com/badminton/racquets?p=4',
#  'https://www.yonex.com/badminton/racquets?p=5',
#  'https://www.yonex.com/badminton/racquets?p=6',
#  'https://www.yonex.com/badminton/racquets?p=7']

# %%
product_urls = []
for url in urls:
    soup = get_soup(url)
    product_urls.extend(get_product_urls(soup))

len(product_urls), product_urls
# Out:
# (78,
#  ['https://www.yonex.com/badminton/racquets/ax02a',
#   'https://www.yonex.com/badminton/racquets/ax02c',
#   'https://www.yonex.com/badminton/racquets/ax02f',
#   'https://www.yonex.com/badminton/racquets/arcsaber-2-ability',
#   'https://www.yonex.com/badminton/racquets/arcsaber-2-feel',
#   'https://www.yonex.com/badminton/racquets/arcsaber-2-clear',
#   'https://www.yonex.com/badminton/racquets/2nf700pl',
#   'https://www.yonex.com/badminton/racquets/2nf-700g',
#   'https://www.yonex.com/badminton/racquets/nanoflare-700-pro',
#   'https://www.yonex.com/badminton/racquets/2nf-700t',
#   'https://www.yonex.com/badminton/racquets/3ax88s-p',
#   'https://www.yonex.com/badminton/racquets/3ax88s-t',
#   'https://www.yonex.com/badminton/racquets/3ax88s-g',
#   'https://www.yonex.com/badminton/racquets/3ax88d-p',
#   'https://www.yonex.com/badminton/racquets/3ax88d-t',
#   'https://www.yonex.com/badminton/racquets/3ax88d-g',
#   'https://www.yonex.com/badminton/racquets/3ax88-pl',
#   'https://www.yonex.com/badminton/racquets/nf-nt',
#   'https://www.yonex.com/badminton/racquets/ax3dg-hf',
#   'https://www.yonex.com/badminton/racquets/ax3dg-st',
#   'https://www.yonex.com/badminton/racquets/nf-800pr',
#   'https://www.yonex.com/badminton/racquets/nf-800t',
#   'https://www.yonex.com/badminton/racquets/nf-800g',
#   'https://www.yonex.com/badminton/racquets/nf800-play',
#   'https://www.yonex.com/badminton/racquets/nf-002c',
#   'https://www.yonex.com/badminton/racquets/nf-002f',
#   'https://www.yonex.com/badminton/racquets/nf-002a',
#   'https://www.yonex.com/badminton/racquets/nf-1000pl',
#   'https://www.yonex.com/badminton/racquets/nf-1000g',
#   'https://www.yonex.com/badminton/racquets/nf-1000t',
#   'https://www.yonex.com/badminton/racquets/nf-1000z',
#   'https://www.yonex.com/badminton/racquets/astrox-77-pro',
#   'https://www.yonex.com/badminton/racquets/astrox-77-tour',
#   'https://www.yonex.com/badminton/racquets/astrox-77-play',
#   'https://www.yonex.com/badminton/racquets/astrox-100zz-ax100zz',
#   'https://www.yonex.com/badminton/racquets/ax100t',
#   'https://www.yonex.com/badminton/racquets/ax100g',
#   'https://www.yonex.com/badminton/racquets/astrox-99-pro-ax99-p',
#   'https://www.yonex.com/badminton/racquets/astrox-99-tour-ax99',
#   'https://www.yonex.com/badminton/racquets/astrox-99-game',
#   'https://www.yonex.com/badminton/racquets/astrox-99-play-ax99',
#   'https://www.yonex.com/badminton/racquets/ax70',
#   'https://www.yonex.com/badminton/racquets/astrox-22-rx',
#   'https://www.yonex.com/badminton/racquets/astrox-22-f',
#   'https://www.yonex.com/badminton/racquets/ax22lt',
#   'https://www.yonex.com/badminton/racquets/axnt',
#   'https://www.yonex.com/badminton/racquets/astrox-ability',
#   'https://www.yonex.com/badminton/racquets/astrox-clear',
#   'https://www.yonex.com/badminton/racquets/astrox-feel',
#   'https://www.yonex.com/badminton/racquets/astrox-7-dg',
#   'https://www.yonex.com/badminton/racquets/astrox-1-dg',
#   'https://www.yonex.com/badminton/racquets/axe13',
#   'https://www.yonex.com/badminton/racquets/arc7-p',
#   'https://www.yonex.com/badminton/racquets/arc7-t',
#   'https://www.yonex.com/badminton/racquets/arc7-pl',
#   'https://www.yonex.com/badminton/racquets/arc11-p',
#   'https://www.yonex.com/badminton/racquets/arc11-t',
#   'https://www.yonex.com/badminton/racquets/arc11-pl',
#   'https://www.yonex.com/badminton/racquets/nf-70',
#   'https://www.yonex.com/badminton/racquets/nanoflare-555',
#   'https://www.yonex.com/badminton/racquets/nanoflare-500',
#   'https://www.yonex.com/badminton/racquets/nanoflare-001-ability',
#   'https://www.yonex.com/badminton/racquets/nanoflare-001-clear',
#   'https://www.yonex.com/badminton/racquets/nanoflare-001-feel',
#   'https://www.yonex.com/badminton/racquets/nf-e13',
#   'https://www.yonex.com/badminton/racquets/duo-zs',
#   'https://www.yonex.com/badminton/racquets/nr-gz',
#   'https://www.yonex.com/badminton/racquets/iso-tr1',
#   'https://www.yonex.com/badminton/racquets/iso-tr0',
#   'https://www.yonex.com/badminton/racquets/isol3',
#   'https://www.yonex.com/badminton/racquets/mp8lt',
#   'https://www.yonex.com/badminton/racquets/mp5lt',
#   'https://www.yonex.com/badminton/racquets/mp2',
#   'https://www.yonex.com/badminton/racquets/mp1',
#   'https://www.yonex.com/badminton/racquets/b7000mdm',
#   'https://www.yonex.com/badminton/racquets/b4000g',
#   'https://www.yonex.com/badminton/racquets/nf-jr',
#   'https://www.yonex.com/badminton/racquets/muscle-power-2-junior-mp2jr'])

# %%
product_infos = []

for url in product_urls:
    soup = get_soup(url)
    product_info = get_product_info(soup)
    product_infos.append(product_info)
    print(product_info)
    
print(f"Successfully scraped {len(product_infos)} products")
# Out:
# {'name': 'ASTROX 02 ABILITY', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players:NANOGY 98Hard Hitters:NANOGY 95', 'Color(s)': 'Red', 'Made In': 'China', 'Item Code': 'AX02A'}
# {'name': 'ASTROX 02 CLEAR', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players:NANOGY 98Hard Hitters:NANOGY 95', 'Color(s)': 'Royal Blue', 'Made In': 'China', 'Item Code': 'AX02C'}
# {'name': 'ASTROX 02 FEEL', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players:NANOGY 98Hard Hitters:NANOGY 95', 'Color(s)': 'Turquoise', 'Made In': 'China', 'Item Code': 'AX02F'}
# {'name': 'ARCSABER 2 ABILITY', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U5,6', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players: NANOGY 98Hard Hitters: NANOGY 95', 'Color(s)': 'Black / Pink', 'Made In': 'China', 'Item Code': 'ARC2A'}
# {'name': 'ARCSABER 2 FEEL', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U5,6', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players: NANOGY 98Hard Hitters: NANOGY 95', 'Color(s)': 'Black / Green', 'Made In': 'China', 'Item Code': 'ARC2F'}
# {'name': 'ARCSABER 2 CLEAR', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U5,6', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players: NANOGY 98Hard Hitters: NANOGY 95', 'Color(s)': 'Black / Blue', 'Made In': 'China', 'Item Code': 'ARC2C'}
# {'name': 'NANOFLARE 700 PLAY', 'Flex': 'Hi-Flex', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple', 'Color(s)': 'Midnight Purple, Silver / Sky Blue', 'Made In': 'China', 'Item Code': '2NF700PL'}
# {'name': 'NANOFLARE 700 GAME', 'Flex': 'Hi-Flex', 'Frame': 'Graphite, Nanocell NEO, HM Graphite, SERVO FILTER', 'Shaft': 'Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U5,6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple', 'Color(s)': 'Midnight Purple, Silver / Sky Blue', 'Made In': 'Taiwan', 'Item Code': '2NF-700G'}
# {'name': 'NANOFLARE 700 PRO', 'Flex': 'Medium', 'Frame': 'HM Graphite, NANOMETRIC DR, M40X, EX-HYPER MG', 'Shaft': 'HM Graphite, SUPER HMG,  ULTRA PE FIBER', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U5,6/5U5,6', 'Stringing Advice': '5U: 19 - 27 lbs4U: 20 - 28 lbs', 'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple', 'Color(s)': 'Midnight Purple', 'Made In': ' Japan', 'Item Code': '2NF-700P'}
# {'name': 'NANOFLARE 700 TOUR', 'Flex': 'Medium', 'Frame': 'HM Graphite, Nanocell NEO, SUPER HMG, SERVO FILTER', 'Shaft': 'HM Graphite, SERVO FILTER', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U5,6/5U5,6', 'Stringing Advice': '5U: 19 - 27 lbs4U: 20 - 28 lbs', 'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple', 'Color(s)': 'Midnight Purple, Silver / Sky Blue', 'Made In': 'Taiwan', 'Item Code': '2NF-700T'}
# {'name': 'ASTROX 88 S PRO', 'Flex': 'STIFF', 'Frame': 'HM Graphite, CFR, Tungsten', 'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE, Ultra PE Fiber', 'Joint': 'NEW Built-in T-Joint', 'Length': '5 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Color(s)': 'Silver / Black', 'Made In': ' Japan', 'Item Code': '3AX88S-P'}
# {'name': 'ASTROX 88 S TOUR', 'Flex': 'STIFF', 'Frame': 'HM Graphite, CSR, Tungsten', 'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE', 'Joint': 'Built-in T-Joint', 'Length': '5 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Color(s)': 'Silver / Black', 'Item Code': '3AX88S-T'}
# {'name': 'ASTROX 88 S GAME', 'Flex': 'Medium', 'Frame': 'HM Graphite, CSR, Tungsten', 'Shaft': 'HM Graphite, 2G-NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '5 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Silver / Black', 'Item Code': '3AX88S-G'}
# {'name': 'ASTROX 88 D PRO', 'Flex': 'STIFF', 'Frame': 'HM Graphite, CFR, Tungsten', 'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE, Ultra PE Fiber', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Color(s)': 'Black / Silver', 'Made In': ' Japan', 'Item Code': '3AX88D-P'}
# {'name': 'ASTROX 88 D TOUR', 'Flex': 'STIFF', 'Frame': 'HM Graphite, CSR, Tungsten', 'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Color(s)': 'Black / Silver', 'Item Code': '3AX88D-T'}
# {'name': 'ASTROX 88 D GAME', 'Flex': 'Medium', 'Frame': 'HM Graphite, CSR, Tungsten', 'Shaft': 'HM Graphite, 2G-NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Black / Silver', 'Item Code': '3AX88D-G'}
# {'name': 'ASTROX 88 PLAY', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Black / Silver', 'Item Code': '3AX88-PL'}
# {'name': 'NANOFLARE NEXTAGE', 'Flex': 'Medium', 'Frame': 'HT Graphite, Nanocell NEO', 'Shaft': 'Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5', 'Stringing Advice': '20 - 28 lbs', 'Recommended String': 'Control Players: SKYARCHard Hitters: NANOGY95', 'Color(s)': 'Dark Gray, White / Gray', 'Item Code': 'NF-NT'}
# {'name': 'ASTROX 3 DG HF', 'Flex': 'Hi-Flex', 'Frame': 'HM Graphite, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 35 lbs', 'Color(s)': 'BLUE/WHITE', 'Item Code': 'AX3DG HF'}
# {'name': 'ASTROX 3 DG ST', 'Flex': 'STIFF', 'Frame': 'HM Graphite, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 35 lbs', 'Color(s)': 'BLACK/BLUE', 'Item Code': 'AX3DG ST'}
# {'name': 'NANOFLARE 800 PRO', 'Flex': 'STIFF', 'Frame': 'HM Graphite, M40X, SUPER HMG, Copper', 'Shaft': 'HM Graphite, SUPER HMG,  ULTRA PE FIBER', 'Joint': 'New Built-in T-Joint, Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs、3U: 21 - 29 lbs', 'Recommended String': 'Control Players: EXBOLT63Hard Hitters: EXBOLT65', 'Color(s)': 'Deep Green', 'Item Code': 'NF-800P'}
# {'name': 'NANOFLARE 800 TOUR', 'Flex': 'STIFF', 'Frame': 'Graphite, Nanocell NEO, HM Graphite, Copper', 'Shaft': 'HM Graphite, SUPER HMG', 'Joint': 'Built-in T-Joint, Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6 ', 'Stringing Advice': '4U: 20 - 28 lbs、3U: 21 - 29 lbs', 'Recommended String': 'Control Players: EXBOLT63Hard Hitters: EXBOLT65', 'Color(s)': 'Deep Green', 'Item Code': 'NF-800T'}
# {'name': 'NANOFLARE 800 GAME', 'Flex': 'Medium', 'Frame': 'Graphite, Nanocell NEO, HM Graphite, Copper', 'Shaft': 'Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '20 - 28 lbs', 'Recommended String': 'Control Players: EXBOLT63Hard Hitters: EXBOLT65', 'Color(s)': 'Deep Green', 'Item Code': 'NF-800G'}
# {'name': 'NANOFLARE 800 PLAY', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '20 - 28 lbs', 'Color(s)': 'Deep Green', 'Item Code': 'NF-800PL'}
# {'name': 'NANOFLARE 002 CLEAR', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players:NANOGY95 /Hard Hitters:NANOGY98', 'Color(s)': 'Yellow', 'Made In': 'China', 'Item Code': 'NF-002C'}
# {'name': 'NANOFLARE 002 FEEL', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players:NANOGY95 /Hard Hitters:NANOGY98', 'Color(s)': 'Magenta', 'Made In': 'China', 'Item Code': 'NF-002F'}
# {'name': 'NANOFLARE 002 ABILITY', 'Flex': 'Hi-Flex', 'Frame': 'HT Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4,5', 'Stringing Advice': '4U: 20 - 30 lbs', 'Recommended String': 'Control Players:NANOGY95 /Hard Hitters:NANOGY98', 'Color(s)': 'Lime', 'Made In': 'China', 'Item Code': 'NF-002A'}
# {'name': 'NANOFLARE 1000 PLAY', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Lightning Yellow', 'Item Code': 'NF-1000PL'}
# {'name': 'NANOFLARE 1000 GAME', 'Flex': 'Medium', 'Shaft': 'Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65', 'Color(s)': 'Lightning Yellow', 'Item Code': 'NF-1000G'}
# {'name': 'NANOFLARE 1000 TOUR', 'Flex': 'Extra Stiff', 'Frame': 'HM Graphite, Nanocell NEO, EX-HYPER MG', 'Shaft': 'HM Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65', 'Color(s)': 'Lightning Yellow', 'Item Code': 'NF-1000T'}
# {'name': 'NANOFLARE 1000 Z', 'Flex': 'Extra Stiff', 'Frame': 'HM Graphite, NANOMETRIC DR, M40X, EX-HYPER MG', 'Shaft': 'HM Graphite, Ultra PE FIBER', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65', 'Color(s)': 'Lightning Yellow', 'Item Code': 'NF-1000Z'}
# {'name': 'ASTROX 77 PRO', 'Flex': 'Medium', 'Frame': 'HM Graphite, Flex Fuse, Tungsten', 'Shaft': 'HM Graphite, Namd™, Ultra PE Fiber', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6 3U (Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 19 - 27 lbs3U: 20 - 28 lbs', 'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65', 'Color(s)': 'High orange', 'Made In': ' Japan', 'Item Code': 'AX77-P'}
# {'name': 'ASTROX 77 TOUR', 'Flex': 'Medium', 'Frame': 'HM Graphite, LIGHT Feel CARBON NEO, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6 3U (Avg. 88g) G4,5,6', 'Stringing Advice': '4U: 20 - 28 lbs、3U: 21 - 29 lbs', 'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65', 'Color(s)': 'High orange', 'Item Code': 'AX77-T'}
# {'name': 'ASTROX 77 PLAY', 'Flex': 'Hi-Flex', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Recommended String': 'Control Players: AEROBITE  Hard Hitters:  EXBOLT65', 'Color(s)': 'High Orange', 'Item Code': 'AX77-PL'}
# {'name': 'ASTROX 100ZZ', 'Flex': 'Extra Stiff', 'Frame': 'HM Graphite, Namd, Tungsten, Black Micro Core, Nanometric', 'Shaft': 'HM Graphite, Namd™', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players: AEROBITE BOOSTHard Hitters: BG66 FORCE', 'Color(s)': 'Kurenai, Dark Navy', 'Made In': 'Japan', 'Item Code': 'AX100ZZ'}
# {'name': 'ASTROX 100 TOUR', 'Flex': 'Extra Stiff', 'Frame': 'HM Graphite, Nanomesh Neo, Tungsten', 'Shaft': 'HM Graphite, Namd™', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players: AEROBITE BOOSTHard Hitters: BG66 FORCE', 'Color(s)': 'Kurenai', 'Item Code': 'AX100T'}
# {'name': 'ASTROX 100 GAME', 'Flex': 'Medium', 'Frame': 'HM Graphite, Nanomesh Neo, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players: AEROBITE BOOSTHard Hitters: BG66 FORCE', 'Color(s)': 'Kurenai', 'Item Code': 'AX100G'}
# {'name': 'ASTROX 99 PRO', 'Flex': 'STIFF', 'Frame': 'HM Graphite, Namd, VOLUME CUT RESIN, Tungsten', 'Shaft': 'HM Graphite, Namd™', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE', 'Color(s)': 'White Tiger, Cherry Sunburst', 'Made In': 'Japan', 'Item Code': 'AX99-P'}
# {'name': 'ASTROX 99 TOUR', 'Flex': 'STIFF', 'Frame': 'HM Graphite, NANOMESH NEO, VOLUME CUT RESIN, Tungsten', 'Shaft': 'HM Graphite, Namd™', 'Joint': 'Built-in T-Joint', 'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE', 'Color(s)': 'White Tiger, Cherry Sunburst', 'Item Code': 'AX99-T'}
# {'name': 'ASTROX 99 GAME', 'Flex': 'Medium', 'Frame': 'HM Graphite, NANOMESH NEO, VOLUME CUT RESIN, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6', 'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs', 'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE', 'Color(s)': 'White Tiger, Cherry Sunburst', 'Item Code': 'AX99-G'}
# {'name': 'ASTROX 99 PLAY', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Weight / Grip': '4U (Avg.83g) G5, 6', 'Stringing Advice': '4U: 20 - 28 lbs', 'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE', 'Color(s)': 'White Tiger, Cherry Sunburst', 'Item Code': 'AX99-PL'}
# {'name': 'ASTROX 70', 'Flex': 'Hi-Flex', 'Frame': 'HM Graphite, VDM, Tungsten', 'Shaft': 'HM Graphite, Namd™', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U 18-26lbs', 'Color(s)': 'Saxe', 'Item Code': 'AX70'}
# {'name': 'ASTROX 22 RX', 'Flex': 'STIFF', 'Frame': 'HM Graphite, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '2F (Avg. 68g) G5, 6', 'Stringing Advice': '2F: 20 - 28 lbs', 'Recommended String': 'Control Players: NANOGY95Hard Hitters: SKYARC', 'Color(s)': 'Black / Gold', 'Item Code': 'AX22RX'}
# {'name': 'ASTROX 22 F', 'Flex': 'Medium', 'Frame': 'HM Graphite, NANOMETRIC DR, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '3F (Avg. 63g) G5', 'Stringing Advice': '3F: 19 - 26 lbs', 'Color(s)': 'Black / Lime', 'Item Code': 'AX22F'}
# {'name': 'ASTROX 22 LT', 'Flex': 'Medium', 'Frame': 'HM Graphite, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Length': '10 mm longer', 'Weight / Grip': '3F (Avg. 63g) G5', 'Stringing Advice': '3F: 19 - 26 lbs', 'Color(s)': 'Black / Red', 'Item Code': 'AX22LT'}
# {'name': 'ASTROX NEXTAGE', 'Flex': 'Medium', 'Frame': 'HM Graphite, VDM, Tungsten', 'Shaft': 'Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U(Avg:83g)5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Recommended String': 'Control Players: BG66 ULTIMAXHard Hitters: BG80', 'Color(s)': 'Light Gray, Black / Green', 'Item Code': 'AXNT'}
# {'name': 'ASTROX ABILITY', 'Flex': 'Hi-Flex', 'Frame': 'Graphite, Tungsten', 'Shaft': 'Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Magenta', 'Item Code': 'AXA'}
# {'name': 'ASTROX CLEAR', 'Flex': 'Hi-Flex', 'Frame': 'Graphite, Tungsten', 'Shaft': 'Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Yellow', 'Item Code': 'AXC'}
# {'name': 'ASTROX FEEL', 'Flex': 'Hi-Flex', 'Frame': 'Graphite, Tungsten', 'Shaft': 'Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Orange', 'Item Code': 'AXF'}
# {'name': 'ASTROX 7 DG', 'Flex': 'Medium', 'Frame': 'HM Graphite, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5', 'Stringing Advice': '4U: 20 - 35 lbs', 'Color(s)': 'Black / Blue', 'Item Code': 'AX7DG'}
# {'name': 'ASTROX 1 DG', 'Flex': 'Hi-Flex', 'Frame': 'HM Graphite, Tungsten', 'Shaft': 'HM Graphite, NANOMESH NEO', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5', 'Stringing Advice': '4U: 20 - 35 lbs', 'Color(s)': 'Blue / Black', 'Item Code': 'AX1DG'}
# {'name': 'ASTROX E 13', 'Frame': 'Aluminum', 'Shaft': 'Graphite', 'Weight / Grip': '3U (Avg. 88g) G4,5', 'Stringing Advice': '3U: 16 - 20 lbs', 'Color(s)': 'Black / Blue, Black / Bright Red', 'Item Code': 'AXE13'}
# {'name': 'ARCSABER 7 PRO', 'Flex': 'Medium', 'Frame': 'HM Graphite, POCKETING BOOSTER', 'Shaft': 'HM Graphite, Ultra PE FIBER', 'Joint': 'NEW Built-in T-Joint, T-ANCHOR', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 6', 'Stringing Advice': '4U: 19 - 27 lbs', 'Recommended String': 'Control Players: EXBOLT 63Hard Hitters: EXBOLT 65', 'Color(s)': 'Gray / Yellow', 'Made In': ' Japan', 'Item Code': 'ARC7-P'}
# {'name': 'ARCSABER 7 TOUR', 'Flex': 'Medium', 'Frame': 'HM Graphite, POCKETING BOOSTER', 'Shaft': 'HM Graphite', 'Joint': 'Built-in T-Joint, T-ANCHOR', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 6', 'Stringing Advice': '4U: 19 - 27 lbs', 'Recommended String': 'Control Players: EXBOLT 63Hard Hitters: EXBOLT 65', 'Color(s)': 'Gray / Yellow', 'Item Code': 'ARC7-T'}
# {'name': 'ARCSABER 7 PLAY', 'Flex': 'Hi-Flex', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Joint': 'Built-in T-Joint, T-ANCHOR', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 6', 'Stringing Advice': '4U: 19 - 27 lbs', 'Recommended String': 'Control Players: EXBOLT 63Hard Hitters: EXBOLT 65', 'Color(s)': 'Gray / Yellow', 'Item Code': 'ARC7-PL'}
# {'name': 'ARCSABER 11 PRO', 'Flex': 'STIFF', 'Frame': 'HM Graphite, POCKETING BOOSTER', 'Shaft': 'HM Graphite, SUPER HMG,  ULTRA PE FIBER', 'Joint': 'NEW Built-in T-Joint, T-ANCHOR', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6', 'Stringing Advice': '4U: 19 - 27 lbs3U: 20 - 28 lbs', 'Color(s)': 'Grayish Pearl', 'Made In': ' Japan', 'Item Code': 'ARC11-P'}
# {'name': 'ARCSABER 11 TOUR', 'Flex': 'STIFF', 'Frame': 'HM Graphite, POCKETING BOOSTER', 'Shaft': 'HM Graphite, SUPER HMG', 'Joint': 'Built-in T-Joint, T-ANCHOR', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6', 'Stringing Advice': '4U: 19 - 27 lbs3U: 20 - 28 lbs', 'Color(s)': 'Grayish Pearl', 'Item Code': 'ARC11-T'}
# {'name': 'ARCSABER 11 PLAY', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg.83g) G5, 6', 'Stringing Advice': '4U: 19 - 27 lbs', 'Color(s)': 'Grayish Pearl', 'Item Code': 'ARC11-PL'}
# {'name': 'NANOFLARE 70', 'Flex': 'Hi-Flex', 'Frame': 'HM Graphite, M40X, SUPER HMG, VDM', 'Shaft': 'HM Graphite', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G5,6', 'Stringing Advice': '4U 18-26lbs', 'Color(s)': 'Coral Pink', 'Made In': ' Japan', 'Item Code': 'NF-70'}
# {'name': 'NANOFLARE 555', 'Flex': 'STIFF', 'Frame': 'HM Graphite, Nanocell NEO, EX-HMG, Solid Titanium', 'Shaft': 'HM Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5', 'Stringing Advice': '4U: 20 - 28 lbs', 'Color(s)': 'Matte White', 'Item Code': 'NF-555'}
# {'name': 'NANOFLARE 500', 'Flex': 'Medium', 'Frame': 'HM Graphite, Nanocell NEO, EX-HMG', 'Shaft': 'HM Graphite', 'Joint': 'Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '5U (Avg. 78g) G4, 54U (Avg. 83g) G4, 5', 'Stringing Advice': '5U: 19 - 26 lbs4U: 20 - 27 lbs', 'Color(s)': 'Matte Black', 'Item Code': 'NF-500'}
# {'name': 'NANOFLARE 001 ABILITY', 'Flex': 'Hi-Flex', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '5U (Avg. 78g) G4, 5', 'Stringing Advice': '5U: 20 - 27 lbs', 'Color(s)': 'Black / Red , Flash Red', 'Item Code': 'NF-001A'}
# {'name': 'NANOFLARE 001 CLEAR', 'Flex': 'Hi-Flex', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '5U (Avg. 78g) G4, 5', 'Stringing Advice': '5U: 20 - 27 lbs', 'Color(s)': 'White / Saxe , Cyan', 'Item Code': 'NF-001C'}
# {'name': 'NANOFLARE 001 FEEL', 'Flex': 'Hi-Flex', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '5U (Avg. 78g) G4, 5', 'Stringing Advice': '5U: 20 - 27 lbs', 'Color(s)': 'White / Mint , Green', 'Item Code': 'NF-001F'}
# {'name': 'NANOFLARE E13', 'Frame': 'Aluminum', 'Shaft': 'Graphite', 'Weight / Grip': '3U (Avg. 88g) G4,5', 'Stringing Advice': '3U: 16 - 20 lbs', 'Color(s)': 'Blue / Red, Turquoise / Yellow', 'Item Code': 'NF-E13'}
# {'name': 'DUORA Z-STRIKE', 'Flex': 'Extra Stiff', 'Frame': 'HM Graphite, NANOMETRIC DR, Hyper-MG', 'Shaft': 'HM Graphite, NANOMETRIC, EX-HMG', 'Joint': 'NEW Built-in T-Joint, T-ANCHOR', 'Length': '10 mm longer', 'Weight / Grip': '3U (Avg. 88g) G4, 52U (Avg. 93g) G4, 5', 'Stringing Advice': '3U: 20 - 28 lbs2U: 21 - 29 lbs', 'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE', 'Color(s)': 'Black / White', 'Made In': ' Japan', 'Item Code': 'DUO-ZS'}
# {'name': 'NANORAY GlanZ', 'Flex': 'Hi-Flex', 'Frame': 'HM Graphite, REXIL FIBER, NANOMETRIC', 'Shaft': 'HM Graphite, NANOMETRIC, X-FULLERENE', 'Joint': 'NEW Built-in T-Joint', 'Length': '10 mm longer', 'Weight / Grip': '4U (Avg. 83g) G4, 5, 6', 'Stringing Advice': '4U: 17 - 22 lbs', 'Recommended String': 'Control Players:SKYARCHard Hitters:NANOGY 98', 'Color(s)': 'Navy / Turquoise', 'Made In': ' Japan', 'Item Code': 'NR-GZ'}
# {'name': 'ISOMETRIC TR 1', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '(Avg. 118g) G4, 5', 'Stringing Advice': 'G4, 5: 20 - 30 lbs', 'Color(s)': 'Blue', 'Item Code': 'ISO-TR1'}
# {'name': 'ISOMETRIC TR 0', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '(Avg. 150g) G4, 5', 'Stringing Advice': 'G4, 5: 20 - 30 lbs', 'Color(s)': 'Green', 'Item Code': 'ISO-TR0'}
# {'name': 'ISOMETRIC LITE 3', 'Flex': 'Medium', 'Frame': 'Graphite', 'Shaft': 'Graphite', 'Length': '10 mm longer', 'Weight / Grip': '3U (Avg. 88g) G4, 5', 'Stringing Advice': '3U: 19 - 24 lbs', 'Color(s)': 'Red, Yellow, Cyan', 'Item Code': 'ISOL3'}
# {'name': 'MUSCLE POWER 8 LT', 'Frame': 'Aluminum', 'Shaft': 'Graphite, Nylon', 'Weight / Grip': '3U (Avg. 88g) G5', 'Stringing Advice': '3U: 16 - 20 lbs', 'Color(s)': 'Orange', 'Item Code': 'MP8LT'}
# {'name': 'MUSCLE POWER 5 LT', 'Frame': 'Aluminum', 'Shaft': 'Steel', 'Stringing Advice': '2U: 16 - 20 lbs', 'Recommended String': '2U (93g) G5', 'Color(s)': 'White / Turquoise', 'Item Code': 'MP5LT'}
# {'name': 'MUSCLE POWER 2', 'Frame': 'Aluminum', 'Shaft': 'Steel', 'Weight / Grip': 'U (105g and below) G4', 'Stringing Advice': 'U: 16 - 20 lbs', 'Color(s)': 'White / Red , White / Yellow', 'Item Code': 'MP2'}
# {'name': 'MUSCLE POWER 1', 'Frame': 'Aluminum', 'Shaft': 'Steel', 'Weight / Grip': 'U (105g and below) G4', 'Stringing Advice': 'U: 16 - 20 lbs', 'Color(s)': 'White / Black , White / Red', 'Item Code': 'MP1'}
# {'name': 'B 7000 MDM', 'Frame': 'Aluminum', 'Shaft': 'Steel', 'Weight / Grip': 'U (105g and below) G4', 'Stringing Advice': 'U: 16 - 20 lbs', 'Color(s)': 'Red, Cyan', 'Item Code': 'B7000MDM'}
# {'name': 'B 4000', 'Frame': 'Aluminum', 'Shaft': 'Steel', 'Weight / Grip': 'U (105g and below) G4', 'Stringing Advice': 'U: 16 - 20 lbs', 'Color(s)': 'Mint, Corn Yellow', 'Item Code': 'B4000'}
# {'name': 'NANOFLARE JUNIOR', 'Flex': 'Hi-Flex', 'Frame': 'Graphite, Nanocell NEO, HM Graphite', 'Shaft': 'Graphite', 'Joint': 'Built-in T-Joint', 'Weight / Grip': '4U (Avg. 83g) G7', 'Stringing Advice': '4U: 17 - 22 lbs', 'Color(s)': 'Cyan', 'Item Code': 'NF-JR'}
# {'name': 'MUSCLE POWER 2 JUNIOR', 'Frame': 'Aluminum', 'Shaft': 'Steel', 'Length': '21 in.', 'Weight / Grip': '4U (Avg. 83g) G5', 'Stringing Advice': '4U: 14 - 18 lbs', 'Color(s)': 'White / Lime Yellow', 'Item Code': 'MP2JR'}
# Successfully scraped 78 products

# %%
product_infos
# Out:
# [{'name': 'ASTROX 02 ABILITY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players:NANOGY 98Hard Hitters:NANOGY 95',
#   'Color(s)': 'Red',
#   'Made In': 'China',
#   'Item Code': 'AX02A'},
#  {'name': 'ASTROX 02 CLEAR',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players:NANOGY 98Hard Hitters:NANOGY 95',
#   'Color(s)': 'Royal Blue',
#   'Made In': 'China',
#   'Item Code': 'AX02C'},
#  {'name': 'ASTROX 02 FEEL',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players:NANOGY 98Hard Hitters:NANOGY 95',
#   'Color(s)': 'Turquoise',
#   'Made In': 'China',
#   'Item Code': 'AX02F'},
#  {'name': 'ARCSABER 2 ABILITY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5,6',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players: NANOGY 98Hard Hitters: NANOGY 95',
#   'Color(s)': 'Black / Pink',
#   'Made In': 'China',
#   'Item Code': 'ARC2A'},
#  {'name': 'ARCSABER 2 FEEL',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5,6',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players: NANOGY 98Hard Hitters: NANOGY 95',
#   'Color(s)': 'Black / Green',
#   'Made In': 'China',
#   'Item Code': 'ARC2F'},
#  {'name': 'ARCSABER 2 CLEAR',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5,6',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players: NANOGY 98Hard Hitters: NANOGY 95',
#   'Color(s)': 'Black / Blue',
#   'Made In': 'China',
#   'Item Code': 'ARC2C'},
#  {'name': 'NANOFLARE 700 PLAY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple',
#   'Color(s)': 'Midnight Purple, Silver / Sky Blue',
#   'Made In': 'China',
#   'Item Code': '2NF700PL'},
#  {'name': 'NANOFLARE 700 GAME',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite, Nanocell NEO, HM Graphite, SERVO FILTER',
#   'Shaft': 'Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple',
#   'Color(s)': 'Midnight Purple, Silver / Sky Blue',
#   'Made In': 'Taiwan',
#   'Item Code': '2NF-700G'},
#  {'name': 'NANOFLARE 700 PRO',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, NANOMETRIC DR, M40X, EX-HYPER MG',
#   'Shaft': 'HM Graphite, SUPER HMG,  ULTRA PE FIBER',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5,6/5U5,6',
#   'Stringing Advice': '5U: 19 - 27 lbs4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple',
#   'Color(s)': 'Midnight Purple',
#   'Made In': ' Japan',
#   'Item Code': '2NF-700P'},
#  {'name': 'NANOFLARE 700 TOUR',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, Nanocell NEO, SUPER HMG, SERVO FILTER',
#   'Shaft': 'HM Graphite, SERVO FILTER',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U5,6/5U5,6',
#   'Stringing Advice': '5U: 19 - 27 lbs4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: EXBOLT63 Hard Hitters: EXBOLT65 The images are Blue and Purple',
#   'Color(s)': 'Midnight Purple, Silver / Sky Blue',
#   'Made In': 'Taiwan',
#   'Item Code': '2NF-700T'},
#  {'name': 'ASTROX 88 S PRO',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, CFR, Tungsten',
#   'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE, Ultra PE Fiber',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '5 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Color(s)': 'Silver / Black',
#   'Made In': ' Japan',
#   'Item Code': '3AX88S-P'},
#  {'name': 'ASTROX 88 S TOUR',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, CSR, Tungsten',
#   'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE',
#   'Joint': 'Built-in T-Joint',
#   'Length': '5 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Color(s)': 'Silver / Black',
#   'Item Code': '3AX88S-T'},
#  {'name': 'ASTROX 88 S GAME',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, CSR, Tungsten',
#   'Shaft': 'HM Graphite, 2G-NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '5 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Silver / Black',
#   'Item Code': '3AX88S-G'},
#  {'name': 'ASTROX 88 D PRO',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, CFR, Tungsten',
#   'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE, Ultra PE Fiber',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Color(s)': 'Black / Silver',
#   'Made In': ' Japan',
#   'Item Code': '3AX88D-P'},
#  {'name': 'ASTROX 88 D TOUR',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, CSR, Tungsten',
#   'Shaft': 'HM Graphite, 2G-Namd™ FLEX FORCE',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,63U (Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Color(s)': 'Black / Silver',
#   'Item Code': '3AX88D-T'},
#  {'name': 'ASTROX 88 D GAME',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, CSR, Tungsten',
#   'Shaft': 'HM Graphite, 2G-NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Black / Silver',
#   'Item Code': '3AX88D-G'},
#  {'name': 'ASTROX 88 PLAY',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Black / Silver',
#   'Item Code': '3AX88-PL'},
#  {'name': 'NANOFLARE NEXTAGE',
#   'Flex': 'Medium',
#   'Frame': 'HT Graphite, Nanocell NEO',
#   'Shaft': 'Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5',
#   'Stringing Advice': '20 - 28 lbs',
#   'Recommended String': 'Control Players: SKYARCHard Hitters: NANOGY95',
#   'Color(s)': 'Dark Gray, White / Gray',
#   'Item Code': 'NF-NT'},
#  {'name': 'ASTROX 3 DG HF',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HM Graphite, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 35 lbs',
#   'Color(s)': 'BLUE/WHITE',
#   'Item Code': 'AX3DG HF'},
#  {'name': 'ASTROX 3 DG ST',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 35 lbs',
#   'Color(s)': 'BLACK/BLUE',
#   'Item Code': 'AX3DG ST'},
#  {'name': 'NANOFLARE 800 PRO',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, M40X, SUPER HMG, Copper',
#   'Shaft': 'HM Graphite, SUPER HMG,  ULTRA PE FIBER',
#   'Joint': 'New Built-in T-Joint, Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs、3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: EXBOLT63Hard Hitters: EXBOLT65',
#   'Color(s)': 'Deep Green',
#   'Item Code': 'NF-800P'},
#  {'name': 'NANOFLARE 800 TOUR',
#   'Flex': 'STIFF',
#   'Frame': 'Graphite, Nanocell NEO, HM Graphite, Copper',
#   'Shaft': 'HM Graphite, SUPER HMG',
#   'Joint': 'Built-in T-Joint, Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6 ',
#   'Stringing Advice': '4U: 20 - 28 lbs、3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: EXBOLT63Hard Hitters: EXBOLT65',
#   'Color(s)': 'Deep Green',
#   'Item Code': 'NF-800T'},
#  {'name': 'NANOFLARE 800 GAME',
#   'Flex': 'Medium',
#   'Frame': 'Graphite, Nanocell NEO, HM Graphite, Copper',
#   'Shaft': 'Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '20 - 28 lbs',
#   'Recommended String': 'Control Players: EXBOLT63Hard Hitters: EXBOLT65',
#   'Color(s)': 'Deep Green',
#   'Item Code': 'NF-800G'},
#  {'name': 'NANOFLARE 800 PLAY',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '20 - 28 lbs',
#   'Color(s)': 'Deep Green',
#   'Item Code': 'NF-800PL'},
#  {'name': 'NANOFLARE 002 CLEAR',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players:NANOGY95 /Hard Hitters:NANOGY98',
#   'Color(s)': 'Yellow',
#   'Made In': 'China',
#   'Item Code': 'NF-002C'},
#  {'name': 'NANOFLARE 002 FEEL',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players:NANOGY95 /Hard Hitters:NANOGY98',
#   'Color(s)': 'Magenta',
#   'Made In': 'China',
#   'Item Code': 'NF-002F'},
#  {'name': 'NANOFLARE 002 ABILITY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HT Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4,5',
#   'Stringing Advice': '4U: 20 - 30 lbs',
#   'Recommended String': 'Control Players:NANOGY95 /Hard Hitters:NANOGY98',
#   'Color(s)': 'Lime',
#   'Made In': 'China',
#   'Item Code': 'NF-002A'},
#  {'name': 'NANOFLARE 1000 PLAY',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Lightning Yellow',
#   'Item Code': 'NF-1000PL'},
#  {'name': 'NANOFLARE 1000 GAME',
#   'Flex': 'Medium',
#   'Shaft': 'Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65',
#   'Color(s)': 'Lightning Yellow',
#   'Item Code': 'NF-1000G'},
#  {'name': 'NANOFLARE 1000 TOUR',
#   'Flex': 'Extra Stiff',
#   'Frame': 'HM Graphite, Nanocell NEO, EX-HYPER MG',
#   'Shaft': 'HM Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65',
#   'Color(s)': 'Lightning Yellow',
#   'Item Code': 'NF-1000T'},
#  {'name': 'NANOFLARE 1000 Z',
#   'Flex': 'Extra Stiff',
#   'Frame': 'HM Graphite, NANOMETRIC DR, M40X, EX-HYPER MG',
#   'Shaft': 'HM Graphite, Ultra PE FIBER',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6、3U(Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65',
#   'Color(s)': 'Lightning Yellow',
#   'Item Code': 'NF-1000Z'},
#  {'name': 'ASTROX 77 PRO',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, Flex Fuse, Tungsten',
#   'Shaft': 'HM Graphite, Namd™, Ultra PE Fiber',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6 3U (Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 19 - 27 lbs3U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65',
#   'Color(s)': 'High orange',
#   'Made In': ' Japan',
#   'Item Code': 'AX77-P'},
#  {'name': 'ASTROX 77 TOUR',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, LIGHT Feel CARBON NEO, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6 3U (Avg. 88g) G4,5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs、3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: AEROBITEHard Hitters: EXBOLT65',
#   'Color(s)': 'High orange',
#   'Item Code': 'AX77-T'},
#  {'name': 'ASTROX 77 PLAY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: AEROBITE  Hard Hitters:  EXBOLT65',
#   'Color(s)': 'High Orange',
#   'Item Code': 'AX77-PL'},
#  {'name': 'ASTROX 100ZZ',
#   'Flex': 'Extra Stiff',
#   'Frame': 'HM Graphite, Namd, Tungsten, Black Micro Core, Nanometric',
#   'Shaft': 'HM Graphite, Namd™',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: AEROBITE BOOSTHard Hitters: BG66 FORCE',
#   'Color(s)': 'Kurenai, Dark Navy',
#   'Made In': 'Japan',
#   'Item Code': 'AX100ZZ'},
#  {'name': 'ASTROX 100 TOUR',
#   'Flex': 'Extra Stiff',
#   'Frame': 'HM Graphite, Nanomesh Neo, Tungsten',
#   'Shaft': 'HM Graphite, Namd™',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: AEROBITE BOOSTHard Hitters: BG66 FORCE',
#   'Color(s)': 'Kurenai',
#   'Item Code': 'AX100T'},
#  {'name': 'ASTROX 100 GAME',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, Nanomesh Neo, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players: AEROBITE BOOSTHard Hitters: BG66 FORCE',
#   'Color(s)': 'Kurenai',
#   'Item Code': 'AX100G'},
#  {'name': 'ASTROX 99 PRO',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, Namd, VOLUME CUT RESIN, Tungsten',
#   'Shaft': 'HM Graphite, Namd™',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE',
#   'Color(s)': 'White Tiger, Cherry Sunburst',
#   'Made In': 'Japan',
#   'Item Code': 'AX99-P'},
#  {'name': 'ASTROX 99 TOUR',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, NANOMESH NEO, VOLUME CUT RESIN, Tungsten',
#   'Shaft': 'HM Graphite, Namd™',
#   'Joint': 'Built-in T-Joint',
#   'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE',
#   'Color(s)': 'White Tiger, Cherry Sunburst',
#   'Item Code': 'AX99-T'},
#  {'name': 'ASTROX 99 GAME',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, NANOMESH NEO, VOLUME CUT RESIN, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg.83g) G5, 63U (Avg.88g) G4, 5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs3U: 21 - 29 lbs',
#   'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE',
#   'Color(s)': 'White Tiger, Cherry Sunburst',
#   'Item Code': 'AX99-G'},
#  {'name': 'ASTROX 99 PLAY',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Weight / Grip': '4U (Avg.83g) G5, 6',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE',
#   'Color(s)': 'White Tiger, Cherry Sunburst',
#   'Item Code': 'AX99-PL'},
#  {'name': 'ASTROX 70',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HM Graphite, VDM, Tungsten',
#   'Shaft': 'HM Graphite, Namd™',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U 18-26lbs',
#   'Color(s)': 'Saxe',
#   'Item Code': 'AX70'},
#  {'name': 'ASTROX 22 RX',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '2F (Avg. 68g) G5, 6',
#   'Stringing Advice': '2F: 20 - 28 lbs',
#   'Recommended String': 'Control Players: NANOGY95Hard Hitters: SKYARC',
#   'Color(s)': 'Black / Gold',
#   'Item Code': 'AX22RX'},
#  {'name': 'ASTROX 22 F',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, NANOMETRIC DR, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '3F (Avg. 63g) G5',
#   'Stringing Advice': '3F: 19 - 26 lbs',
#   'Color(s)': 'Black / Lime',
#   'Item Code': 'AX22F'},
#  {'name': 'ASTROX 22 LT',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Length': '10 mm longer',
#   'Weight / Grip': '3F (Avg. 63g) G5',
#   'Stringing Advice': '3F: 19 - 26 lbs',
#   'Color(s)': 'Black / Red',
#   'Item Code': 'AX22LT'},
#  {'name': 'ASTROX NEXTAGE',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, VDM, Tungsten',
#   'Shaft': 'Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U(Avg:83g)5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Recommended String': 'Control Players: BG66 ULTIMAXHard Hitters: BG80',
#   'Color(s)': 'Light Gray, Black / Green',
#   'Item Code': 'AXNT'},
#  {'name': 'ASTROX ABILITY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite, Tungsten',
#   'Shaft': 'Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Magenta',
#   'Item Code': 'AXA'},
#  {'name': 'ASTROX CLEAR',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite, Tungsten',
#   'Shaft': 'Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Yellow',
#   'Item Code': 'AXC'},
#  {'name': 'ASTROX FEEL',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite, Tungsten',
#   'Shaft': 'Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Orange',
#   'Item Code': 'AXF'},
#  {'name': 'ASTROX 7 DG',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5',
#   'Stringing Advice': '4U: 20 - 35 lbs',
#   'Color(s)': 'Black / Blue',
#   'Item Code': 'AX7DG'},
#  {'name': 'ASTROX 1 DG',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HM Graphite, Tungsten',
#   'Shaft': 'HM Graphite, NANOMESH NEO',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5',
#   'Stringing Advice': '4U: 20 - 35 lbs',
#   'Color(s)': 'Blue / Black',
#   'Item Code': 'AX1DG'},
#  {'name': 'ASTROX E 13',
#   'Frame': 'Aluminum',
#   'Shaft': 'Graphite',
#   'Weight / Grip': '3U (Avg. 88g) G4,5',
#   'Stringing Advice': '3U: 16 - 20 lbs',
#   'Color(s)': 'Black / Blue, Black / Bright Red',
#   'Item Code': 'AXE13'},
#  {'name': 'ARCSABER 7 PRO',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, POCKETING BOOSTER',
#   'Shaft': 'HM Graphite, Ultra PE FIBER',
#   'Joint': 'NEW Built-in T-Joint, T-ANCHOR',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 6',
#   'Stringing Advice': '4U: 19 - 27 lbs',
#   'Recommended String': 'Control Players: EXBOLT 63Hard Hitters: EXBOLT 65',
#   'Color(s)': 'Gray / Yellow',
#   'Made In': ' Japan',
#   'Item Code': 'ARC7-P'},
#  {'name': 'ARCSABER 7 TOUR',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, POCKETING BOOSTER',
#   'Shaft': 'HM Graphite',
#   'Joint': 'Built-in T-Joint, T-ANCHOR',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 6',
#   'Stringing Advice': '4U: 19 - 27 lbs',
#   'Recommended String': 'Control Players: EXBOLT 63Hard Hitters: EXBOLT 65',
#   'Color(s)': 'Gray / Yellow',
#   'Item Code': 'ARC7-T'},
#  {'name': 'ARCSABER 7 PLAY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Joint': 'Built-in T-Joint, T-ANCHOR',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 6',
#   'Stringing Advice': '4U: 19 - 27 lbs',
#   'Recommended String': 'Control Players: EXBOLT 63Hard Hitters: EXBOLT 65',
#   'Color(s)': 'Gray / Yellow',
#   'Item Code': 'ARC7-PL'},
#  {'name': 'ARCSABER 11 PRO',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, POCKETING BOOSTER',
#   'Shaft': 'HM Graphite, SUPER HMG,  ULTRA PE FIBER',
#   'Joint': 'NEW Built-in T-Joint, T-ANCHOR',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6',
#   'Stringing Advice': '4U: 19 - 27 lbs3U: 20 - 28 lbs',
#   'Color(s)': 'Grayish Pearl',
#   'Made In': ' Japan',
#   'Item Code': 'ARC11-P'},
#  {'name': 'ARCSABER 11 TOUR',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, POCKETING BOOSTER',
#   'Shaft': 'HM Graphite, SUPER HMG',
#   'Joint': 'Built-in T-Joint, T-ANCHOR',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5, 63U (Avg. 88g) G4, 5, 6',
#   'Stringing Advice': '4U: 19 - 27 lbs3U: 20 - 28 lbs',
#   'Color(s)': 'Grayish Pearl',
#   'Item Code': 'ARC11-T'},
#  {'name': 'ARCSABER 11 PLAY',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg.83g) G5, 6',
#   'Stringing Advice': '4U: 19 - 27 lbs',
#   'Color(s)': 'Grayish Pearl',
#   'Item Code': 'ARC11-PL'},
#  {'name': 'NANOFLARE 70',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HM Graphite, M40X, SUPER HMG, VDM',
#   'Shaft': 'HM Graphite',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G5,6',
#   'Stringing Advice': '4U 18-26lbs',
#   'Color(s)': 'Coral Pink',
#   'Made In': ' Japan',
#   'Item Code': 'NF-70'},
#  {'name': 'NANOFLARE 555',
#   'Flex': 'STIFF',
#   'Frame': 'HM Graphite, Nanocell NEO, EX-HMG, Solid Titanium',
#   'Shaft': 'HM Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5',
#   'Stringing Advice': '4U: 20 - 28 lbs',
#   'Color(s)': 'Matte White',
#   'Item Code': 'NF-555'},
#  {'name': 'NANOFLARE 500',
#   'Flex': 'Medium',
#   'Frame': 'HM Graphite, Nanocell NEO, EX-HMG',
#   'Shaft': 'HM Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '5U (Avg. 78g) G4, 54U (Avg. 83g) G4, 5',
#   'Stringing Advice': '5U: 19 - 26 lbs4U: 20 - 27 lbs',
#   'Color(s)': 'Matte Black',
#   'Item Code': 'NF-500'},
#  {'name': 'NANOFLARE 001 ABILITY',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '5U (Avg. 78g) G4, 5',
#   'Stringing Advice': '5U: 20 - 27 lbs',
#   'Color(s)': 'Black / Red , Flash Red',
#   'Item Code': 'NF-001A'},
#  {'name': 'NANOFLARE 001 CLEAR',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '5U (Avg. 78g) G4, 5',
#   'Stringing Advice': '5U: 20 - 27 lbs',
#   'Color(s)': 'White / Saxe , Cyan',
#   'Item Code': 'NF-001C'},
#  {'name': 'NANOFLARE 001 FEEL',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '5U (Avg. 78g) G4, 5',
#   'Stringing Advice': '5U: 20 - 27 lbs',
#   'Color(s)': 'White / Mint , Green',
#   'Item Code': 'NF-001F'},
#  {'name': 'NANOFLARE E13',
#   'Frame': 'Aluminum',
#   'Shaft': 'Graphite',
#   'Weight / Grip': '3U (Avg. 88g) G4,5',
#   'Stringing Advice': '3U: 16 - 20 lbs',
#   'Color(s)': 'Blue / Red, Turquoise / Yellow',
#   'Item Code': 'NF-E13'},
#  {'name': 'DUORA Z-STRIKE',
#   'Flex': 'Extra Stiff',
#   'Frame': 'HM Graphite, NANOMETRIC DR, Hyper-MG',
#   'Shaft': 'HM Graphite, NANOMETRIC, EX-HMG',
#   'Joint': 'NEW Built-in T-Joint, T-ANCHOR',
#   'Length': '10 mm longer',
#   'Weight / Grip': '3U (Avg. 88g) G4, 52U (Avg. 93g) G4, 5',
#   'Stringing Advice': '3U: 20 - 28 lbs2U: 21 - 29 lbs',
#   'Recommended String': 'Control Players:AEROBITEHard Hitters:BG66 FORCE',
#   'Color(s)': 'Black / White',
#   'Made In': ' Japan',
#   'Item Code': 'DUO-ZS'},
#  {'name': 'NANORAY GlanZ',
#   'Flex': 'Hi-Flex',
#   'Frame': 'HM Graphite, REXIL FIBER, NANOMETRIC',
#   'Shaft': 'HM Graphite, NANOMETRIC, X-FULLERENE',
#   'Joint': 'NEW Built-in T-Joint',
#   'Length': '10 mm longer',
#   'Weight / Grip': '4U (Avg. 83g) G4, 5, 6',
#   'Stringing Advice': '4U: 17 - 22 lbs',
#   'Recommended String': 'Control Players:SKYARCHard Hitters:NANOGY 98',
#   'Color(s)': 'Navy / Turquoise',
#   'Made In': ' Japan',
#   'Item Code': 'NR-GZ'},
#  {'name': 'ISOMETRIC TR 1',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '(Avg. 118g) G4, 5',
#   'Stringing Advice': 'G4, 5: 20 - 30 lbs',
#   'Color(s)': 'Blue',
#   'Item Code': 'ISO-TR1'},
#  {'name': 'ISOMETRIC TR 0',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '(Avg. 150g) G4, 5',
#   'Stringing Advice': 'G4, 5: 20 - 30 lbs',
#   'Color(s)': 'Green',
#   'Item Code': 'ISO-TR0'},
#  {'name': 'ISOMETRIC LITE 3',
#   'Flex': 'Medium',
#   'Frame': 'Graphite',
#   'Shaft': 'Graphite',
#   'Length': '10 mm longer',
#   'Weight / Grip': '3U (Avg. 88g) G4, 5',
#   'Stringing Advice': '3U: 19 - 24 lbs',
#   'Color(s)': 'Red, Yellow, Cyan',
#   'Item Code': 'ISOL3'},
#  {'name': 'MUSCLE POWER 8 LT',
#   'Frame': 'Aluminum',
#   'Shaft': 'Graphite, Nylon',
#   'Weight / Grip': '3U (Avg. 88g) G5',
#   'Stringing Advice': '3U: 16 - 20 lbs',
#   'Color(s)': 'Orange',
#   'Item Code': 'MP8LT'},
#  {'name': 'MUSCLE POWER 5 LT',
#   'Frame': 'Aluminum',
#   'Shaft': 'Steel',
#   'Stringing Advice': '2U: 16 - 20 lbs',
#   'Recommended String': '2U (93g) G5',
#   'Color(s)': 'White / Turquoise',
#   'Item Code': 'MP5LT'},
#  {'name': 'MUSCLE POWER 2',
#   'Frame': 'Aluminum',
#   'Shaft': 'Steel',
#   'Weight / Grip': 'U (105g and below) G4',
#   'Stringing Advice': 'U: 16 - 20 lbs',
#   'Color(s)': 'White / Red , White / Yellow',
#   'Item Code': 'MP2'},
#  {'name': 'MUSCLE POWER 1',
#   'Frame': 'Aluminum',
#   'Shaft': 'Steel',
#   'Weight / Grip': 'U (105g and below) G4',
#   'Stringing Advice': 'U: 16 - 20 lbs',
#   'Color(s)': 'White / Black , White / Red',
#   'Item Code': 'MP1'},
#  {'name': 'B 7000 MDM',
#   'Frame': 'Aluminum',
#   'Shaft': 'Steel',
#   'Weight / Grip': 'U (105g and below) G4',
#   'Stringing Advice': 'U: 16 - 20 lbs',
#   'Color(s)': 'Red, Cyan',
#   'Item Code': 'B7000MDM'},
#  {'name': 'B 4000',
#   'Frame': 'Aluminum',
#   'Shaft': 'Steel',
#   'Weight / Grip': 'U (105g and below) G4',
#   'Stringing Advice': 'U: 16 - 20 lbs',
#   'Color(s)': 'Mint, Corn Yellow',
#   'Item Code': 'B4000'},
#  {'name': 'NANOFLARE JUNIOR',
#   'Flex': 'Hi-Flex',
#   'Frame': 'Graphite, Nanocell NEO, HM Graphite',
#   'Shaft': 'Graphite',
#   'Joint': 'Built-in T-Joint',
#   'Weight / Grip': '4U (Avg. 83g) G7',
#   'Stringing Advice': '4U: 17 - 22 lbs',
#   'Color(s)': 'Cyan',
#   'Item Code': 'NF-JR'},
#  {'name': 'MUSCLE POWER 2 JUNIOR',
#   'Frame': 'Aluminum',
#   'Shaft': 'Steel',
#   'Length': '21 in.',
#   'Weight / Grip': '4U (Avg. 83g) G5',
#   'Stringing Advice': '4U: 14 - 18 lbs',
#   'Color(s)': 'White / Lime Yellow',
#   'Item Code': 'MP2JR'}]

# %%
import pandas as pd

df = pd.DataFrame(product_infos)
df.set_index('name', inplace=True)
df.to_csv('yonex_racquets.csv')
df
# Out:
#                           Flex                                Frame     Shaft  \
# name
# ASTROX 02 ABILITY      Hi-Flex                          HT Graphite  Graphite
# ASTROX 02 CLEAR        Hi-Flex                          HT Graphite  Graphite
# ASTROX 02 FEEL         Hi-Flex                          HT Graphite  Graphite
# ARCSABER 2 ABILITY     Hi-Flex                          HT Graphite  Graphite
# ARCSABER 2 FEEL        Hi-Flex                          HT Graphite  Graphite
# ...                        ...                                  ...       ...
# MUSCLE POWER 1             NaN                             Aluminum     Steel
# B 7000 MDM                 NaN                             Aluminum     Steel
# B 4000                     NaN                             Aluminum     Steel
# NANOFLARE JUNIOR       Hi-Flex  Graphite, Nanocell NEO, HM Graphite  Graphite
# MUSCLE POWER 2 JUNIOR      NaN                             Aluminum     Steel
#
#                              Length          Weight / Grip Stringing Advice  \
# name
# ASTROX 02 ABILITY      10 mm longer     4U (Avg. 83g) G4,5  4U: 20 - 30 lbs
# ASTROX 02 CLEAR        10 mm longer     4U (Avg. 83g) G4,5  4U: 20 - 30 lbs
# ASTROX 02 FEEL         10 mm longer     4U (Avg. 83g) G4,5  4U: 20 - 30 lbs
# ARCSABER 2 ABILITY     10 mm longer                  4U5,6  4U: 20 - 30 lbs
# ARCSABER 2 FEEL        10 mm longer                  4U5,6  4U: 20 - 30 lbs
# ...                             ...                    ...              ...
# MUSCLE POWER 1                  NaN  U (105g and below) G4   U: 16 - 20 lbs
# B 7000 MDM                      NaN  U (105g and below) G4   U: 16 - 20 lbs
# B 4000                          NaN  U (105g and below) G4   U: 16 - 20 lbs
# NANOFLARE JUNIOR                NaN       4U (Avg. 83g) G7  4U: 17 - 22 lbs
# MUSCLE POWER 2 JUNIOR        21 in.       4U (Avg. 83g) G5  4U: 14 - 18 lbs
#
#                                                       Recommended String  \
# name
# ASTROX 02 ABILITY        Control Players:NANOGY 98Hard Hitters:NANOGY 95
# ASTROX 02 CLEAR          Control Players:NANOGY 98Hard Hitters:NANOGY 95
# ASTROX 02 FEEL           Control Players:NANOGY 98Hard Hitters:NANOGY 95
# ARCSABER 2 ABILITY     Control Players: NANOGY 98Hard Hitters: NANOGY 95
# ARCSABER 2 FEEL        Control Players: NANOGY 98Hard Hitters: NANOGY 95
# ...                                                                  ...
# MUSCLE POWER 1                                                       NaN
# B 7000 MDM                                                           NaN
# B 4000                                                               NaN
# NANOFLARE JUNIOR                                                     NaN
# MUSCLE POWER 2 JUNIOR                                                NaN
#
#                                           Color(s) Made In Item Code  \
# name
# ASTROX 02 ABILITY                              Red   China     AX02A
# ASTROX 02 CLEAR                         Royal Blue   China     AX02C
# ASTROX 02 FEEL                           Turquoise   China     AX02F
# ARCSABER 2 ABILITY                    Black / Pink   China     ARC2A
# ARCSABER 2 FEEL                      Black / Green   China     ARC2F
# ...                                            ...     ...       ...
# MUSCLE POWER 1         White / Black , White / Red     NaN       MP1
# B 7000 MDM                               Red, Cyan     NaN  B7000MDM
# B 4000                           Mint, Corn Yellow     NaN     B4000
# NANOFLARE JUNIOR                              Cyan     NaN     NF-JR
# MUSCLE POWER 2 JUNIOR          White / Lime Yellow     NaN     MP2JR
#
#                                   Joint
# name
# ASTROX 02 ABILITY                   NaN
# ASTROX 02 CLEAR                     NaN
# ASTROX 02 FEEL                      NaN
# ARCSABER 2 ABILITY                  NaN
# ARCSABER 2 FEEL                     NaN
# ...                                 ...
# MUSCLE POWER 1                      NaN
# B 7000 MDM                          NaN
# B 4000                              NaN
# NANOFLARE JUNIOR       Built-in T-Joint
# MUSCLE POWER 2 JUNIOR               NaN
#
# [78 rows x 11 columns]
